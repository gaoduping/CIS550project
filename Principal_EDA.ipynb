# %%
import pandas as pd
prefix = '/content/drive'
from google.colab import drive
drive.mount(prefix, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/title.principals.tsv'
title_principals=pd.read_csv(file_path,sep='\t')

# %%
title_principals
