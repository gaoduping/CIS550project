# %%
import pandas as pd
prefix = '/content/drive'
from google.colab import drive
drive.mount(prefix, force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/CIS550 Project/the_oscar_award.csv'
oscar=pd.read_csv(file_path)

# %% [markdown]
# Keep the awards for actor and actress only.

# %%
oscar = oscar[oscar['category'].isin(['ACTOR','ACTRESS'])]

# %%
oscar.dtypes
# Out:
#       year_film  year_ceremony  ceremony category                 name  \
# 0          1927           1928         1    ACTOR  Richard Barthelmess
# 1          1927           1928         1    ACTOR        Emil Jannings
# 2          1927           1928         1  ACTRESS       Louise Dresser
# 3          1927           1928         1  ACTRESS         Janet Gaynor
# 4          1927           1928         1  ACTRESS       Gloria Swanson
# ...         ...            ...       ...      ...                  ...
# 5308       1975           1976        48  ACTRESS      Isabelle Adjani
# 5309       1975           1976        48  ACTRESS          Ann-Margret
# 5310       1975           1976        48  ACTRESS      Louise Fletcher
# 5311       1975           1976        48  ACTRESS       Glenda Jackson
# 5312       1975           1976        48  ACTRESS           Carol Kane
#
#                                  film  winner
# 0                           The Noose   False
# ...

# %%
oscar.groupby(['name','film']).size()
# Out:
# name            film
# Adolphe Menjou  The Front Page                  1
# Al Pacino       Dog Day Afternoon               1
#                 Serpico                         1
#                 The Godfather Part II           1
# Alan Arkin      The Heart Is a Lonely Hunter    1
#                                                ..
# William Holden  Sunset Blvd.                    1
# William Powell  Life with Father                1
#                 My Man Godfrey                  1
#                 The Thin Man                    1
# Yul Brynner     The King and I                  1
# Length: 468, dtype: int64
